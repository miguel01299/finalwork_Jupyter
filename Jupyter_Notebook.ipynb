# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Miguel Ángel Jiménez Peralta**
# -
# Desired job: Data Scientist

# %% [markdown]
# *I am interested in data science because data is the future*

# %% [markdown]
# ### This code does a product of -3 and 2

# %%
-3*2
# Out:
# -6

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
# -
# | Nombre | Edad |
# | ------ | ------ |
# | Juan | 19 |
# | ------ | ------ |
# | Inés | 22 |
# -
# >Hola, esto esto es un ejemplo de Blocked quotes
# -
#
# ![GENOVESES](attachment:10eb3e81-bca1-48c4-a5ca-ed93b930a9df.jpg)
